# %%
import numpy as np

# %%
a = np.array([1,2,3])
b = np.array([[1,2,3],[4,5,6]])
print(type(a))
print(a.shape)
print (type(b))
print(b.shape)
print (a[0],b[1,1])
# Out:
# <class 'numpy.ndarray'>
# (3,)
# <class 'numpy.ndarray'>
# (2, 3)
# 1 5
