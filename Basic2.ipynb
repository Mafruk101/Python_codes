# %%
l = ['a','b',1,2,3.5]
t = (3.3,4.1, 'c','d')
print(l)
print(t)
# Out:
# ['a', 'b', 1, 2, 3.5]
# (3.3, 4.1, 'c', 'd')

# %%
print(l[2],t[1],t[-2])
# Out:
# 1 4.1 c

# %%
for i in t:
    print(i)
# Out:
# 3.3
# 4.1
# c
# d

# %%
for i in l:
    print(i)
# Out:
# a
# b
# 1
# 2
# 3.5

# %%
for i,v in enumerate(l):
    print(f"{i}:{v}")
# Out:
# 0:a
# 1:b
# 2:1
# 3:2
# 4:3.5

# %%
c=[]
c.append('a')
c.append('b')
c.append("c")
print(c)
# Out:
# ['a', 'b', 'c']

# %%
print(c)
c.insert(0,"x")
print(c)
# Out:
# ['c', 'b', 'a']
# ['x', 'c', 'b', 'a']

# %%
print(c)
c.remove('x')
print(c)
# Out:
# ['x', 'c', 'b', 'a']
# ['c', 'b', 'a']

# %%
del c[0]
print(c)
# Out:
# ['b', 'a']
